# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/0.10GSD_v2.zip -x '**/.DS_Store'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: 0.10GSD_v2/data/ppe/dataset/test/0000001111-1-Image_jpeg.rf.e4c2a613d083d794ce5d0319712ef508.xml
#   inflating: __MACOSX/0.10GSD_v2/data/ppe/dataset/test/._0000001111-1-Image_jpeg.rf.e4c2a613d083d794ce5d0319712ef508.xml
#   inflating: 0.10GSD_v2/data/ppe/dataset/test/0000000963-1-Image_jpeg.rf.d5e72c8d8648a1e98fef5aa5cbe89470.jpg
#   inflating: __MACOSX/0.10GSD_v2/data/ppe/dataset/test/._0000000963-1-Image_jpeg.rf.d5e72c8d8648a1e98fef5aa5cbe89470.jpg
#   inflating: 0.10GSD_v2/data/ppe/dataset/test/0000000359-1-Image_jpeg.rf.526c3fa0a47aa08f391844e0a8f77b9c.xml
#   inflating: __MACOSX/0.10GSD_v2/data/ppe/dataset/test/._0000000359-1-Image_jpeg.rf.526c3fa0a47aa08f391844e0a8f77b9c.xml
#   inflating: 0.10GSD_v2/data/ppe/dataset/test/0000001394-1-Image_jpeg.rf.d0ba3184d573f982bcc28b7fb6d62433.jpg
#   inflating: __MACOSX/0.10GSD_v2/data/ppe/dataset/test/._0000001394-1-Image_jpeg.rf.d0ba3184d573f982bcc28b7fb6d62433.jpg
# ...

# %%
# %cd 0.10GSD_v2
# Out:
# /content/0.10GSD_v2

# %%
# !python train.py --model fasterrcnn_resnet50_fpn_v2 --config data_configs/ppe.yaml --epochs 50 --project-name fasterrcnn_resnet50_fpn_v2_ppe --use-train-aug --no-mosaic
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Number of training samples: 1026
# Number of validation samples: 440
#
# Building model from scratch...
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_v2_coco-dd69338a.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_v2_coco-dd69338a.pth
# 100% 167M/167M [00:01<00:00, 135MB/s]
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
# ...
